# %% [markdown]
# # 03 Training Pipeline
# Train TGN + CQL and inspect uncertainty gated actions.

# %%
# !pip -q install -r ../requirements.txt

# %%
import sys
sys.path.append('..')
from main import run
run()
